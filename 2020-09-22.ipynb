# %% [markdown]
# # Himalayan Climbing Expeditions
#
# [TidyTuesday 2020-09-22](https://github.com/rfordatascience/tidytuesday/tree/master/data/2020/2020-09-22)

# %% [markdown]
# **Contents:**
#
# * [Setup and data load](#Setup-and-data-load)
# * [Success / survival predictive features](#Success-/-survival-predictive-features)
# * [Encode for modeling](#Encode-for-modeling)
# * [Where do climbers come from?](#Where-do-climbers-come-from?)

# %% [markdown]
# ## Setup and data load

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import model_selection, linear_model, metrics

import geopandas as gpd
import pycrs
from shapely.geometry.polygon import Polygon
from shapely.geometry.multipolygon import MultiPolygon

# %%
pd.set_option('display.max_columns', None)

# %%
base_url = 'https://github.com/rfordatascience/tidytuesday/raw/master/data/2020/2020-09-22'
expeditions = pd.read_csv(f'{base_url}/expeditions.csv')
members = pd.read_csv(f'{base_url}/members.csv')
peaks = pd.read_csv(f'{base_url}/peaks.csv')

# %%
print(expeditions.shape)
expeditions.head()
# Out:
# (10364, 16)
#   expedition_id peak_id     peak_name  year  season basecamp_date  \
# 0     ANN260101    ANN2  Annapurna II  1960  Spring    1960-03-15
# 1     ANN269301    ANN2  Annapurna II  1969  Autumn    1969-09-25
# 2     ANN273101    ANN2  Annapurna II  1973  Spring    1973-03-16
# 3     ANN278301    ANN2  Annapurna II  1978  Autumn    1978-09-08
# 4     ANN279301    ANN2  Annapurna II  1979  Autumn           NaN
#
#   highpoint_date termination_date                termination_reason  \
# 0     1960-05-17              NaN               Success (main peak)
# 1     1969-10-22       1969-10-26               Success (main peak)
# 2     1973-05-06              NaN               Success (main peak)
# 3     1978-10-02       1978-10-05  Bad weather (storms, high winds)
# 4     1979-10-18       1979-10-20  Bad weather (storms, high winds)
#
#    highpoint_metres  members  member_deaths  hired_staff  hired_staff_deaths  \
# 0            7937.0       10              0            9                   0
# 1            7937.0       10              0            0                   0
# 2            7937.0        6              0            8                   0
# 3            7000.0        2              0            0                   0
# 4            7160.0        3              0            0                   0
#
#    oxygen_used trekking_agency
# 0         True             NaN
# 1        False             NaN
# 2        False             NaN
# 3        False             NaN
# 4        False             NaN

# %%
print(members.shape)
members.head()
# Out:
# (76519, 21)
#   expedition_id     member_id peak_id   peak_name  year  season sex   age  \
# 0     AMAD78301  AMAD78301-01    AMAD  Ama Dablam  1978  Autumn   M  40.0
# 1     AMAD78301  AMAD78301-02    AMAD  Ama Dablam  1978  Autumn   M  41.0
# 2     AMAD78301  AMAD78301-03    AMAD  Ama Dablam  1978  Autumn   M  27.0
# 3     AMAD78301  AMAD78301-04    AMAD  Ama Dablam  1978  Autumn   M  40.0
# 4     AMAD78301  AMAD78301-05    AMAD  Ama Dablam  1978  Autumn   M  34.0
#
#   citizenship expedition_role  hired  highpoint_metres  success   solo  \
# 0      France          Leader  False               NaN    False  False
# 1      France   Deputy Leader  False            6000.0    False  False
# 2      France         Climber  False               NaN    False  False
# 3      France      Exp Doctor  False            6000.0    False  False
# 4      France         Climber  False               NaN    False  False
#
#    oxygen_used   died death_cause  death_height_metres  injured injury_type  \
# 0        False  False         NaN                  NaN    False         NaN
# 1        False  False         NaN                  NaN    False         NaN
# 2        False  False         NaN                  NaN    False         NaN
# 3        False  False         NaN                  NaN    False         NaN
# 4        False  False         NaN                  NaN    False         NaN
#
#    injury_height_metres
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
print(peaks.shape)
peaks.head()
# Out:
# (468, 8)
#   peak_id      peak_name peak_alternative_name  height_metres climbing_status  \
# 0    AMAD     Ama Dablam          Amai Dablang           6814         Climbed
# 1    AMPG  Amphu Gyabjen                   NaN           5630         Climbed
# 2    ANN1    Annapurna I                   NaN           8091         Climbed
# 3    ANN2   Annapurna II                   NaN           7937         Climbed
# 4    ANN3  Annapurna III                   NaN           7555         Climbed
#
#    first_ascent_year  first_ascent_country first_ascent_expedition_id
# 0             1961.0  New Zealand, USA, UK                  AMAD61101
# 1             1953.0                    UK                  AMPG53101
# 2             1950.0                France                  ANN150101
# 3             1960.0             UK, Nepal                  ANN260101
# 4             1961.0                 India                  ANN361101

# %% [markdown]
# ## Success / survival predictive features

# %%
D = members['peak_id year season sex age citizenship expedition_role solo oxygen_used success died injured'.split()]
D = D.merge(peaks['peak_id height_metres'.split()], on='peak_id').drop(columns='peak_id')
D
# Out:
#        year  season sex   age citizenship expedition_role   solo  oxygen_used  \
# 0      1978  Autumn   M  40.0      France          Leader  False        False
# 1      1978  Autumn   M  41.0      France   Deputy Leader  False        False
# 2      1978  Autumn   M  27.0      France         Climber  False        False
# 3      1978  Autumn   M  40.0      France      Exp Doctor  False        False
# 4      1978  Autumn   M  34.0      France         Climber  False        False
# ...     ...     ...  ..   ...         ...             ...    ...          ...
# 76499  2019  Spring   M  31.0       Nepal      H-A Worker  False        False
# 76500  2019  Spring   M  35.0       Nepal      H-A Worker  False        False
# 76501  2019  Spring   M  56.0     Austria          Leader  False        False
# 76502  2019  Spring   F  57.0     Austria         Climber  False        False
# 76503  2019  Spring   M  41.0       Nepal      H-A Worker  False        False
#
#        success   died  injured  height_metres
# 0        False  False    False           6814
# 1        False  False    False           6814
# 2        False  False    False           6814
# 3        False  False    False           6814
# 4        False  False    False           6814
# ...        ...    ...      ...            ...
# 76499     True  False    False           6151
# 76500     True  False    False           6151
# 76501     True  False    False           6452
# 76502    False  False    False           6452
# 76503     True  False    False           6452
#
# [76504 rows x 12 columns]

# %%
D.season.value_counts().plot.barh(figsize=(4,2)).grid()

# %%
D.sex.value_counts().plot.barh(figsize=(4,2)).grid()

# %%
D.oxygen_used.value_counts().plot.barh(figsize=(4,2)).grid()

# %%
D.solo.value_counts().plot.barh(figsize=(4,2)).grid()

# %%
D.age.hist(bins=np.r_[:100], figsize=(4,2));

# %%
D.height_metres.hist(bins=50, figsize=(4,2));

# %%
D.expedition_role.nunique(), D.citizenship.nunique()
# Out:
# (524, 212)

# %%
d = D.citizenship.value_counts().sort_values(ascending=False).reset_index().head(50)
print(d.citizenship.sum() / len(members))
fig, ax = plt.subplots(figsize=(5,8))
sns.barplot('citizenship', 'index', data=d, ax=ax)
ax.set(xlabel='Number of climber-tries', ylabel='');
# Out:
# 0.9791685725114024

# %% [markdown]
# ## Encode for modeling

# %% [markdown]
# Start with numerical and binary features, then manually one-hot encode categoricals:

# %%
d = D.dropna()
targets = 'success injured died'.split()
XY = d[targets + 'year age height_metres oxygen_used'.split()].copy()
for c in 'season sex citizenship'.split():
    for value in D[c].value_counts().sort_values(ascending=False).head(20).index:
        XY[f'{c}_is_{value}'] = D[c].eq(value)
predictors = XY.columns[len(targets):]
XY
# Out:
#        success  injured   died  year   age  height_metres  oxygen_used  \
# 0        False    False  False  1978  40.0           6814        False
# 1        False    False  False  1978  41.0           6814        False
# 2        False    False  False  1978  27.0           6814        False
# 3        False    False  False  1978  40.0           6814        False
# 4        False    False  False  1978  34.0           6814        False
# ...        ...      ...    ...   ...   ...            ...          ...
# 76499     True    False  False  2019  31.0           6151        False
# 76500     True    False  False  2019  35.0           6151        False
# 76501     True    False  False  2019  56.0           6452        False
# 76502    False    False  False  2019  57.0           6452        False
# 76503     True    False  False  2019  41.0           6452        False
#
#        season_is_Spring  season_is_Autumn  season_is_Winter  season_is_Summer  \
# 0                 False              True             False             False
# 1                 False              True             False             False
# 2                 False              True             False             False
# 3                 False              True             False             False
# 4                 False              True             False             False
# ...                 ...               ...               ...               ...
# 76499              True             False             False             False
# 76500              True             False             False             False
# 76501              True             False             False             False
# 76502              True             False             False             False
# 76503              True             False             False             False
#
#        season_is_Unknown  sex_is_M  sex_is_F  citizenship_is_Nepal  \
# 0                  False      True     False                 False
# 1                  False      True     False                 False
# 2                  False      True     False                 False
# 3                  False      True     False                 False
# 4                  False      True     False                 False
# ...                  ...       ...       ...                   ...
# 76499              False      True     False                  True
# 76500              False      True     False                  True
# 76501              False      True     False                 False
# 76502              False     False      True                 False
# 76503              False      True     False                  True
#
#        citizenship_is_USA  citizenship_is_Japan  citizenship_is_UK  \
# 0                   False                 False              False
# 1                   False                 False              False
# 2                   False                 False              False
# 3                   False                 False              False
# 4                   False                 False              False
# ...                   ...                   ...                ...
# 76499               False                 False              False
# 76500               False                 False              False
# 76501               False                 False              False
# 76502               False                 False              False
# 76503               False                 False              False
#
#        citizenship_is_France  citizenship_is_Spain  citizenship_is_S Korea  \
# 0                       True                 False                   False
# 1                       True                 False                   False
# 2                       True                 False                   False
# 3                       True                 False                   False
# 4                       True                 False                   False
# ...                      ...                   ...                     ...
# 76499                  False                 False                   False
# 76500                  False                 False                   False
# 76501                  False                 False                   False
# 76502                  False                 False                   False
# 76503                  False                 False                   False
#
#        citizenship_is_Italy  citizenship_is_Germany  \
# 0                     False                   False
# 1                     False                   False
# 2                     False                   False
# 3                     False                   False
# 4                     False                   False
# ...                     ...                     ...
# 76499                 False                   False
# 76500                 False                   False
# 76501                 False                   False
# 76502                 False                   False
# 76503                 False                   False
#
#        citizenship_is_Switzerland  citizenship_is_China  \
# 0                           False                 False
# 1                           False                 False
# 2                           False                 False
# 3                           False                 False
# 4                           False                 False
# ...                           ...                   ...
# 76499                       False                 False
# 76500                       False                 False
# 76501                       False                 False
# 76502                       False                 False
# 76503                       False                 False
#
#        citizenship_is_Austria  citizenship_is_India  citizenship_is_Australia  \
# 0                       False                 False                     False
# 1                       False                 False                     False
# 2                       False                 False                     False
# 3                       False                 False                     False
# 4                       False                 False                     False
# ...                       ...                   ...                       ...
# 76499                   False                 False                     False
# 76500                   False                 False                     False
# 76501                    True                 False                     False
# 76502                    True                 False                     False
# 76503                   False                 False                     False
#
#        citizenship_is_Poland  citizenship_is_Russia  citizenship_is_Canada  \
# 0                      False                  False                  False
# 1                      False                  False                  False
# 2                      False                  False                  False
# 3                      False                  False                  False
# 4                      False                  False                  False
# ...                      ...                    ...                    ...
# 76499                  False                  False                  False
# 76500                  False                  False                  False
# 76501                  False                  False                  False
# 76502                  False                  False                  False
# 76503                  False                  False                  False
#
#        citizenship_is_New Zealand  citizenship_is_W Germany  \
# 0                           False                     False
# 1                           False                     False
# 2                           False                     False
# 3                           False                     False
# 4                           False                     False
# ...                           ...                       ...
# 76499                       False                     False
# 76500                       False                     False
# 76501                       False                     False
# 76502                       False                     False
# 76503                       False                     False
#
#        citizenship_is_Netherlands
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# ...                           ...
# 76499                       False
# 76500                       False
# 76501                       False
# 76502                       False
# 76503                       False
#
# [72985 rows x 34 columns]

# %%
XYtrain, XYtest = model_selection.train_test_split(XY.sort_values('year'), test_size=.1, shuffle=False)
Xtrain, Xtest = XYtrain.drop(columns=targets), XYtest.drop(columns=targets)
XYtrain.year.min(), XYtrain.year.max(), XYtest.year.min(), XYtest.year.max()
# Out:
# (1905, 2016, 2016, 2019)

# %%
models = {
    target: linear_model.LogisticRegressionCV(solver='liblinear').fit(Xtrain, XYtrain[target])
    for target in targets
}

# %%
for (target, model) in models.items():
    print(target)
    print(metrics.classification_report(XYtest[target], model.predict(Xtest),
                                        zero_division=0))
    print()
# Out:
# success
#               precision    recall  f1-score   support
#
#        False       0.71      0.73      0.72      2621
#         True       0.85      0.83      0.84      4678
#
#     accuracy                           0.79      7299
#    macro avg       0.78      0.78      0.78      7299
# weighted avg       0.80      0.79      0.80      7299
#
#
# injured
#               precision    recall  f1-score   support
#
#        False       0.98      1.00      0.99      7159
#         True       0.00      0.00      0.00       140
#
#     accuracy                           0.98      7299
#    macro avg       0.49      0.50      0.50      7299
# weighted avg       0.96      0.98      0.97      7299
#
#
# died
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      1.00      7243
#         True       0.00      0.00      0.00        56
#
#     accuracy                           0.99      7299
#    macro avg       0.50      0.50      0.50      7299
# weighted avg       0.98      0.99      0.99      7299

# %%
{
    target: metrics.roc_auc_score(XYtest[target], model.predict_proba(Xtest)[:,1])
    for (target, model) in models.items()
}
# Out:
# {'success': 0.838888681366129,
#  'injured': 0.5422510127112725,
#  'died': 0.4528954064022406}

# %% [markdown]
# It turns out it was pretty silly to try to predict injury or death – those outcomes are simply too rare, especially in recent times.  Success has also been on the rise, but it was always common enough to appear in both the train and test sets.

# %%
fig, ax = plt.subplots()
for (i, target) in enumerate(targets):
    color = f'C{i}'
    ax.plot(XYtrain.groupby('year')[target].mean(), color=color, ls=':')
    ax.plot(XYtest.groupby('year')[target].mean(), color=color, label=target)
ax.legend();

# %% [markdown]
# We can inspect the features used in the predictions:

# %%
d = pd.DataFrame(dict(c=models['success'].coef_[0], name=predictors))
d = d.sort_values('c', ascending=False)

fig, ax = plt.subplots(figsize=(4,6))
sns.barplot('c', 'name', data=d, ax=ax,
            palette=sns.color_palette("RdBu_r", len(d)))
ax.set(xlabel='coefficient', ylabel='')
ax.grid()

# %% [markdown]
# Oxygen use seems to be the best predictor of success.

# %% [markdown]
# ## Where do climbers come from?

# %%
d = D[D.year.ge(1950) & D.citizenship.isin(D.citizenship.value_counts().head(10).index)]
ax = sns.lineplot('year', 0, 'citizenship', data=d.groupby('year citizenship'.split()).size().reset_index())
#ticks, labels = ax.get_xticks(), ax.get_xticklabels()
#ax.set(xticks=ticks[::10], xticklabels=labels[::10]);

# %% [markdown]
# Set up world geometry...

# %%
# base geometry
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.crs = {'init': 'epsg:4326'}

# add boundary
lons, lats = np.linspace(-180, 180, 100), np.linspace(-90, 90, 100)
boundary = Polygon(
    [(lon, -90) for lon in lons]
    + [(180, lat) for lat in lats]
    + [(lon, 90) for lon in reversed(lons)]
    + [(-180, lat) for lat in reversed(lats)])
bworld = world.append(pd.Series(dict(
    continent='Border', iso_a3='boundary', geometry=boundary)), ignore_index=True)

# project
# 54030: Robertson
pworld = bworld.to_crs(pycrs.parse.from_esri_code(54030).to_proj4())
# Out:
# /Users/mrichman/ve/main/lib/python3.6/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
fig, ax = plt.subplots(figsize=(8,6), dpi=120)

c = pd.Series('/'.join(members.citizenship.dropna().astype(str)).split('/'))
c = (
    c.str.replace('USA', 'United States of America')
    .str.replace('^N ', 'North ')
    .str.replace('^S ', 'South ')
    .str.replace('^E ', 'East ')
    .str.replace('^W ', 'West ')
    .str.replace('^UK$', 'United Kingdom')
)
dd = d = c.value_counts().reset_index()
d.columns = 'name N'.split()
d = pworld.merge(d, on='name', how='left').fillna(0)
pworld.boundary.plot(color='k', lw=.25, ax=ax)
d.plot(
    'N', ax=ax,
    norm=plt.matplotlib.colors.LogNorm(vmin=1, vmax=d.N.max()),
    legend=True, legend_kwds=dict(
        orientation='horizontal', fraction=.03, pad=0, ax=ax,
        label='Number of Attempts',
    ),
)
ax.axis('off')
plt.tight_layout()

# %% [markdown]
# ## The peaks

# %%
peaks.sort_values('height_metres', ascending=False).head()
# Out:
#     peak_id      peak_name                peak_alternative_name  \
# 42     EVER        Everest  Sagarmatha, Chomolungma, Qomolungma
# 91     KANG  Kangchenjunga                                  NaN
# 112    LHOT         Lhotse                                  NaN
# 188    YALU    Yalung Kang                            Yalungkar
# 122    MAKA         Makalu                                  NaN
#
#      height_metres climbing_status  first_ascent_year first_ascent_country  \
# 42            8850         Climbed             1953.0   New Zealand, India
# 91            8586         Climbed             1955.0                   UK
# 112           8516         Climbed             1956.0          Switzerland
# 188           8505         Climbed             1973.0                Japan
# 122           8485         Climbed             1955.0               France
#
#     first_ascent_expedition_id
# 42                   EVER53101
# 91                   KANG55101
# 112                  LHOT56101
# 188                  YALU73101
# 122                  MAKA55101

# %%
peaks.climbing_status.value_counts().plot.barh(figsize=(4,2));

# %%
fig, ax = plt.subplots()
mask = peaks.climbing_status.eq('Climbed')
ax.hist(peaks.height_metres[mask], bins=20, alpha=.5, label='Climbed')
ax.hist(peaks.height_metres[~mask], bins=20, alpha=.5, label='Never climbed')
ax.legend()
ax.set(xlabel='Peak Height [m]', ylabel='Number of Peaks');

# %%
peaks.first_ascent_year.min()
# Out:
# 201.0

# %%
peaks.loc[peaks.first_ascent_year.eq(201), 'first_ascent_year'] = 2010

# %%
fig, ax = plt.subplots()
ax.plot(peaks.height_metres, peaks.first_ascent_year, '.')
ax.set(xlabel='Height [m]', ylabel='First Ascent Year');

# %%
d = expeditions.peak_id.value_counts().reset_index().head(20)
d.columns = 'peak_id counts'.split()
d = d.merge(peaks, on='peak_id')
ax = sns.barplot('counts', 'peak_name', data=d)
for (i, row) in d.iterrows():
    ax.text(row.counts+3, i, f'{int(row.first_ascent_year)}', va='center', color='.5')
ax.set(xlabel='Number of Attempts', ylabel='');
